# %% [markdown]
# ## Importing libraries

# %%
# %pip install powerlaw

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import powerlaw
from scipy.stats import lognorm
# Out:
# Requirement already satisfied: powerlaw in c:\users\adith\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: scipy in c:\users\adith\anaconda3\lib\site-packages (from powerlaw) (1.13.1)
# Requirement already satisfied: numpy in c:\users\adith\anaconda3\lib\site-packages (from powerlaw) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\adith\anaconda3\lib\site-packages (from powerlaw) (3.9.2)
# Requirement already satisfied: mpmath in c:\users\adith\anaconda3\lib\site-packages (from powerlaw) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adith\anaconda3\lib\site-packages (from matplotlib->powerlaw) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\adith\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->powerlaw) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('Forward.csv')
df.head(10)
# Out:
#                                   Most Cited Records  Total
# 0  IN447594A1 | MILLIMETER-WAV SURFACE-WAVE COMMU...    162
# 1  IN201647015348A | MILLIMETER-WAV SURFACE-WAVE ...    162
# 2  IN-CHENP-2015-07352A | REMOTE DISTRIBUTED ANTE...     91
# 3  IN309092A1 | WIRELESS NON-RADIATIVE ENERGY TRA...     55
# 4  IN-DELNP-2009-06195A | WIRELESS ENERGY TRANSFE...     55
# 5  IN-DELNP-2008-00735A | WIRELESS NON-RADIATIVE ...     55
# 6  IN261253A1 | SYSTEM USING CASCADED GAIN ELEMEN...     38
# 7  IN-DELNP-2004-02290A | TRANSPONDER, INCLUDING ...     38
# 8  IN201747044027A | SYSTEM AND METHOD FOR SOUND ...     36
# 9  IN531925A1 | AN IMPROVED ORGANIC RANKINE CYCLE...     32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Most Cited Records  100 non-null    object
#  1   Total               100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Display

# %% [markdown]
# ### Display the first few rows of the data

# %%
print("Data Table:")
print(df[["Most Cited Records", "Total"]].head())
print(f"Total number of patents considered: {len(df)}")
# Out:
# Data Table:
#                                   Most Cited Records  Total
# 0  IN447594A1 | MILLIMETER-WAV SURFACE-WAVE COMMU...    162
# 1  IN201647015348A | MILLIMETER-WAV SURFACE-WAVE ...    162
# 2  IN-CHENP-2015-07352A | REMOTE DISTRIBUTED ANTE...     91
# 3  IN309092A1 | WIRELESS NON-RADIATIVE ENERGY TRA...     55
# 4  IN-DELNP-2009-06195A | WIRELESS ENERGY TRANSFE...     55
# Total number of patents considered: 100

# %% [markdown]
# ### Emperical distribution

# %%
# Extract and sort citation counts in descending order
total_citations = df['Total']
total_citations_sorted = total_citations.sort_values(ascending=False)

# Calculate ranks and empirical distribution
ranks = np.arange(1, len(total_citations_sorted) + 1)
empirical_distribution = total_citations_sorted.cumsum() / total_citations_sorted.sum()

# Combine ranks and empirical distribution into a DataFrame
empirical_data = pd.DataFrame({'Rank': ranks, 'Empirical Distribution': empirical_distribution})

# Step 5: Plot the empirical distribution
plt.figure(figsize=(10, 6))
plt.plot(empirical_data['Rank'], empirical_data['Empirical Distribution'], 'g-', lw=2, label='Empirical Distribution')
plt.xlabel('Rank')
plt.ylabel('Empirical Distribution')
plt.title('Empirical Distribution of Total Citations')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Lognormal fit

# %%
# Extract the 'Total' column (citation counts)
total_citations = df['Total']

# Fit a lognormal distribution to the citation data
shape, loc, scale = lognorm.fit(total_citations)

# Generate x values for plotting
x = np.linspace(min(total_citations), max(total_citations), 100)

# Calculate the PDF of the fitted lognormal distribution
pdf = lognorm.pdf(x, shape, loc, scale)

# Plot the histogram and lognormal fit
plt.figure(figsize=(10, 6))
plt.hist(total_citations, bins=30, density=True, alpha=0.5, label='Citation Data')
plt.plot(x, pdf, 'r-', lw=2, label=f'Lognormal Fit (shape={shape:.2f}, loc={loc:.2f}, scale={scale:.2f})')

# Add labels and title
plt.xlabel('Total Citations')
plt.ylabel('Density')
plt.title('Lognormal Fit on Citation Data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Power law fit

# %%
# Load the CSV file
data = pd.read_csv('Forward.csv')

# Extract citation counts
total_citations = data['Total']

# Sort citation counts in descending order
total_citations_sorted = np.sort(total_citations)[::-1]

# Calculate ranks for each citation count
ranks = np.arange(1, len(total_citations_sorted) + 1)

# Log-transform the ranks and citation counts
log_ranks = np.log10(ranks)
log_citations = np.log10(total_citations_sorted)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(log_ranks, log_citations, 'b-', lw=2, label='Power Law Distribution')
plt.xlabel('Log(Rank)')
plt.ylabel('Log(Total Citations)')
plt.title('Power Law Distribution of Total Citations')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pareto distribution

# %%
# Extract citation counts
total_citations = df['Total']

# Sort citations in descending order
total_citations_sorted = np.sort(total_citations)[::-1]

import matplotlib.pyplot as plt

# Create Pareto plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(total_citations_sorted) + 1), total_citations_sorted, 'r-', lw=2, label='Pareto Distribution')
plt.xlabel('Rank')
plt.ylabel('Total Citations')
plt.title('Pareto Distribution of Total Citations')
plt.legend()
plt.grid(True)
plt.show()
